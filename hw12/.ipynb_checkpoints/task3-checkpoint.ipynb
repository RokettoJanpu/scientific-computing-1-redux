# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from Levenberg_Marquardt import LevenbergMarquardt
import random

# %%
# Read mnist data from the mat file
mnist_data = scipy.io.loadmat("mnist2.mat")
imgs_train = mnist_data['imgs_train']
imgs_test = mnist_data['imgs_test']
labels_train = np.squeeze(mnist_data['labels_train'])
labels_test = np.squeeze(mnist_data['labels_test'])
print(np.shape(imgs_train))
print(np.shape(imgs_test))
print(np.shape(labels_train))
print(np.shape(labels_test))
print(labels_train[:100])
d1,d2,N = np.shape(imgs_train)
# Out:
# (20, 20, 60000)
# (20, 20, 10000)
# (60000,)
# (10000,)
# [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1 7 2 8 6 9 4 0 9 1 1 2 4 3 2 7 3 8 6 9 0 5 6
#  0 7 6 1 8 7 9 3 9 8 5 9 3 3 0 7 4 9 8 0 9 4 1 4 4 6 0 4 5 6 1 0 0 1 7 1 6
#  3 0 2 1 1 7 9 0 2 6 7 8 3 9 0 4 6 7 4 6 8 0 7 8 3 1]

# %%
# Select images of 1 and 7
Itrain_1 = np.where(labels_train == 1)
Itrain_7 = np.where(labels_train == 7)
Itest_1 = np.where(labels_test == 1)
Itest_7 = np.where(labels_test == 7)
imgs_train_1 = np.squeeze(imgs_train[:,:,Itrain_1])
imgs_train_7 = np.squeeze(imgs_train[:,:,Itrain_7])
imgs_test_1 = np.squeeze(imgs_test[:,:,Itest_1])
imgs_test_7 = np.squeeze(imgs_test[:,:,Itest_7])
Ntrain_1 = np.size(Itrain_1)
Ntrain_7 = np.size(Itrain_7)
Ntest_1 = np.size(Itest_1)
Ntest_7 = np.size(Itest_7)
print(f"Ntrain_1 = {Ntrain_1}, Ntrain_7 = {Ntrain_7}")
print(f"Ntest_1 = {Ntest_1}, Ntest_7 = {Ntest_7}")
# Out:
# Ntrain_1 = 6742, Ntrain_7 = 6265
# Ntest_1 = 1135, Ntest_7 = 1028

# %%
# Dsiplay the first 100 images of 1
m1 = 10
m2 = 10
fig, axs = plt.subplots(m1,m2)
for i in range(m1):
    for j in range(m2):
        img = np.squeeze(imgs_train_1[:,:,i*m2+j])
        axs[i,j].imshow(img)
        axs[i,j].axis("off")

# %%
# Dsiplay the first 100 images of 7
m1 = 10
m2 = 10
fig, axs = plt.subplots(m1,m2)
for i in range(m1):
    for j in range(m2):
        img = np.squeeze(imgs_train_7[:,:,i*m2+j])
        axs[i,j].imshow(img)
        axs[i,j].axis("off")

# %%
# Use PCA to reduce the dimensionality to nPCA
NPCA = 20

dd = d1*d2
X1 = np.zeros((Ntrain_1,dd))
X7 = np.zeros((Ntrain_7,dd))
for j in range(Ntrain_1):
    img = np.squeeze(imgs_train_1[:,:,j])
    X1[j,:] = np.reshape(img,(dd,))
for j in range(Ntrain_7):
    img = np.squeeze(imgs_train_7[:,:,j])
    X7[j,:] = np.reshape(img,(dd,))
X = np.concatenate((X1,X7),axis = 0)
print(np.shape(X))
U,S,Vtrans = np.linalg.svd(X,full_matrices = False)
print(f"U: {np.shape(U)}; S: {np.shape(S)}; Vtrans: {np.shape(Vtrans)}")
V = np.transpose(Vtrans)
Xtrain = np.matmul(X,V[:,:NPCA])
print(f"Xtrain: {np.shape(Xtrain)}")
# Out:
# (13007, 400)
# U: (13007, 400); S: (400,); Vtrans: (400, 400)
# Xtrain: (13007, 20)

# %%
# Prepare the test set
X1test = np.zeros((Ntest_1,dd))
X7test = np.zeros((Ntest_7,dd))
for j in range(Ntest_1):
    img = np.squeeze(imgs_test_1[:,:,j])
    X1test[j,:] = np.reshape(img,(dd,))
for j in range(Ntest_7):
    img = np.squeeze(imgs_test_7[:,:,j])
    X7test[j,:] = np.reshape(img,(dd,))
Xtest = np.concatenate((X1test,X7test),axis = 0)
Xtest = np.matmul(Xtest,V[:,:NPCA])
print(f"Xtest: {np.shape(Xtest)}")
# Out:
# Xtest: (2163, 20)

# %%
# prepare labels for the train and test sets: ones have label 1, sevens have label -1
Ntrain = Ntrain_1 + Ntrain_7
Ntest = Ntest_1 + Ntest_7
lbl_train = np.ones((Ntrain,))
lbl_train[Ntrain_1:] = -1
lbl_test = np.ones((Ntest,))
lbl_test[Ntest_1:] = -1

# %%
# Define functions for finding the optimal dividing surface
def logloss_quadratic(X,y,w):
    return 0.5*np.sum((np.log(1. + np.exp(-myquadratic(X,y,w))))**2)

def Res_and_Jac(X,y,w):
    # the vector of residuals r
    aux = np.exp(-myquadratic(X,y,w))
    r = np.log(1. + aux)
    # the Jacobian matrix J[i,j] = dr[i]/dx[j]
    a = -aux/(1. + aux)
    n,d = np.shape(X)
    d2 = d*d
    ya = y*a
    qterm = np.zeros((n,d2))
    for k in range(n):
        xk = X[k,:]
        xx = np.outer(xk,xk)
        qterm[k,:] = np.reshape(xx,(np.size(xx),))
    J = np.concatenate((qterm,X,np.ones((n,1))),axis = 1)   
    for k in range(n):
        J[k,:] = J[k,:]*ya[k]
    return r,J

def myquadratic(X,y,w):
    d = np.size(X,axis = 1)
    d2 = d*d
    W = np.reshape(w[:d2],(d,d))
    v = w[d2:d2+d];
    b = w[-1]
    qterm = np.diag(X@W@np.transpose(X))
    q = y*qterm + (np.outer(y,np.ones((d,)))*X)@v + y*b
    return q

# %%
# Generates a random subset of k elements from the set {0, 1, ..., n-1}
def random_subset(n, k):
    return random.sample(range(n), k)

# %%
random_subset(10,3)
# Out:
# [8, 9, 4]

# %%
# task 3: stochastic gradient
d = NPCA
def r_and_J(w):
    return Res_and_Jac(Xtrain,lbl_train,w)
def Loss(w):
    return logloss_quadratic(Xtrain,lbl_train,w)
# The quadratic surface is of the form x^\top W x + v x + b 
# The total number of parameters in W,v,b is d^2 + d + 1
# The initial guess: all parameters are ones
w = np.ones((d*d + d + 1,))
iter_max = 600
tol = 1e-3
c = 0.1
rho = 0.9

f = Loss(w)
r,J = r_and_J(w)
Jt = J.T
g = Jt@r
norm_g = np.linalg.norm(g)
print(f"Initially: loss = {f:.4e}, gradnorm = {norm_g}")

Loss_vals = np.zeros(iter_max)
Loss_vals[0] = f
gradnorm_vals = np.zeros(iter_max)
gradnorm_vals[0] = norm_g

iter = 1

while (norm_g > tol and iter < iter_max):

    # find direction p by solving J^T*Jp = -g, where g = J^T*r is the gradient
    # add a term 1e-6*I to avoid singular LHS
    p = np.linalg.solve(Jt@J+1e-6*np.eye(d*d + d + 1), -g)

    # normalize the search direction if its length is greater than 1
    norm_p = np.linalg.norm(p)
    if(norm_p > 1):
        p = p/norm_p
    # do backtracking line search along the direction p
    a = 1 # initial step length
    f_temp = Loss(w)
    cpg = c*np.dot(p,g)
    while(f_temp > f + a*cpg): # check Wolfe's condition 1
        a = a*rho
        if(a < 1e-14):
            print("line search failed\n");
            iter = iter_max-1
            break
        f_temp = Loss(w + a*p)
        
    w = w + a*p
    f = Loss(w)
    r,J = r_and_J(w)
    Jt = J.T
    g = Jt@r
    norm_g = np.linalg.norm(g)
    print(f"iter {iter}: loss = {f:.6f}, gradnorm = {norm_g:.6e}, step length = {a:.3e}")
    Loss_vals[iter] = f
    gradnorm_vals[iter] = norm_g
    iter = iter + 1
print(f"Result: loss = {f:.10f}, gradnorm = {norm_g:.6e}")
# Out:
# Initially: loss = 4.0021e+07, gradnorm = 26687972.461658176
# iter 1: loss = 36586418.474099, gradnorm = 2.551703e+07, step length = 9.000e-01
# iter 2: loss = 33306587.963134, gradnorm = 2.434621e+07, step length = 9.000e-01
# iter 3: loss = 30181110.889416, gradnorm = 2.317551e+07, step length = 9.000e-01
# iter 4: loss = 27209968.049963, gradnorm = 2.200495e+07, step length = 9.000e-01
# iter 5: loss = 24393138.731013, gradnorm = 2.083454e+07, step length = 9.000e-01
# iter 6: loss = 21730600.654460, gradnorm = 1.966431e+07, step length = 9.000e-01
# iter 7: loss = 19222329.921930, gradnorm = 1.849427e+07, step length = 9.000e-01
# iter 8: loss = 16868300.960274, gradnorm = 1.732446e+07, step length = 9.000e-01
# iter 9: loss = 14668486.449004, gradnorm = 1.615490e+07, step length = 9.000e-01
# iter 10: loss = 12622857.210560, gradnorm = 1.498564e+07, step length = 9.000e-01
# iter 11: loss = 10731382.032709, gradnorm = 1.381673e+07, step length = 9.000e-01
# iter 12: loss = 8994027.363251, gradnorm = 1.264826e+07, step length = 9.000e-01
# iter 13: loss = 7410756.808381, gradnorm = 1.148034e+07, step length = 9.000e-01
# iter 14: loss = 5981530.324238, gradnorm = 1.031311e+07, step length = 9.000e-01
# iter 15: loss = 4706302.916827, gradnorm = 9.146808e+06, step length = 9.000e-01
# iter 16: loss = 3585022.463408, gradnorm = 7.981786e+06, step length = 9.000e-01
# iter 17: loss = 2617625.620169, gradnorm = 6.818626e+06, step length = 9.000e-01
# iter 18: loss = 1804028.836049, gradnorm = 5.658350e+06, step length = 9.000e-01
# iter 19: loss = 1144106.389315, gradnorm = 4.502940e+06, step length = 9.000e-01
# iter 20: loss = 637636.458375, gradnorm = 3.356827e+06, step length = 9.000e-01
# iter 21: loss = 284157.583527, gradnorm = 2.232547e+06, step length = 9.000e-01
# iter 22: loss = 81851.523049, gradnorm = 1.180435e+06, step length = 9.000e-01
# iter 23: loss = 11658.905867, gradnorm = 4.041250e+05, step length = 9.000e-01
# iter 24: loss = 833.249155, gradnorm = 5.644093e+04, step length = 9.000e-01
# iter 25: loss = 169.025926, gradnorm = 1.047995e+04, step length = 9.000e-01
# iter 26: loss = 71.454268, gradnorm = 3.279607e+03, step length = 9.000e-01
# iter 27: loss = 41.901700, gradnorm = 1.407737e+03, step length = 9.000e-01
# iter 28: loss = 28.607837, gradnorm = 7.375681e+02, step length = 9.000e-01
# iter 29: loss = 21.234586, gradnorm = 4.470640e+02, step length = 9.000e-01
# iter 30: loss = 16.546029, gradnorm = 2.997366e+02, step length = 9.000e-01
# iter 31: loss = 13.286557, gradnorm = 2.156180e+02, step length = 9.000e-01
# iter 32: loss = 10.883776, gradnorm = 1.629675e+02, step length = 9.000e-01
# iter 33: loss = 9.039978, gradnorm = 1.275379e+02, step length = 9.000e-01
# iter 34: loss = 7.584106, gradnorm = 1.023116e+02, step length = 9.000e-01
# iter 35: loss = 6.410123, gradnorm = 8.357949e+01, step length = 9.000e-01
# iter 36: loss = 5.447243, gradnorm = 6.920760e+01, step length = 9.000e-01
# iter 37: loss = 4.646159, gradnorm = 5.787873e+01, step length = 9.000e-01
# iter 38: loss = 3.971895, gradnorm = 4.874588e+01, step length = 9.000e-01
# iter 39: loss = 3.399363, gradnorm = 4.125002e+01, step length = 9.000e-01
# iter 40: loss = 2.910238, gradnorm = 3.501307e+01, step length = 9.000e-01
# iter 41: loss = 2.490757, gradnorm = 2.977173e+01, step length = 9.000e-01
# iter 42: loss = 2.130233, gradnorm = 2.533651e+01, step length = 9.000e-01
# iter 43: loss = 1.820112, gradnorm = 2.156644e+01, step length = 9.000e-01
# iter 44: loss = 1.553369, gradnorm = 1.835314e+01, step length = 9.000e-01
# iter 45: loss = 1.324109, gradnorm = 1.561071e+01, step length = 9.000e-01
# iter 46: loss = 1.127297, gradnorm = 1.326913e+01, step length = 9.000e-01
# iter 47: loss = 0.958574, gradnorm = 1.127009e+01, step length = 9.000e-01
# iter 48: loss = 0.814146, gradnorm = 9.564329e+00, step length = 9.000e-01
# iter 49: loss = 0.690693, gradnorm = 8.109784e+00, step length = 9.000e-01
# iter 50: loss = 0.585315, gradnorm = 6.870398e+00, step length = 9.000e-01
# iter 51: loss = 0.495484, gradnorm = 5.815198e+00, step length = 9.000e-01
# iter 52: loss = 0.419001, gradnorm = 4.917579e+00, step length = 9.000e-01
# iter 53: loss = 0.353964, gradnorm = 4.154707e+00, step length = 9.000e-01
# iter 54: loss = 0.298729, gradnorm = 3.506997e+00, step length = 9.000e-01
# iter 55: loss = 0.251877, gradnorm = 2.957653e+00, step length = 9.000e-01
# iter 56: loss = 0.212187, gradnorm = 2.492255e+00, step length = 9.000e-01
# iter 57: loss = 0.178606, gradnorm = 2.098410e+00, step length = 9.000e-01
# iter 58: loss = 0.150224, gradnorm = 1.765464e+00, step length = 9.000e-01
# iter 59: loss = 0.126262, gradnorm = 1.484270e+00, step length = 9.000e-01
# iter 60: loss = 0.106050, gradnorm = 1.246995e+00, step length = 9.000e-01
# iter 61: loss = 0.089015, gradnorm = 1.046948e+00, step length = 9.000e-01
# iter 62: loss = 0.074670, gradnorm = 8.784228e-01, step length = 9.000e-01
# iter 63: loss = 0.062599, gradnorm = 7.365589e-01, step length = 9.000e-01
# iter 64: loss = 0.052449, gradnorm = 6.172193e-01, step length = 9.000e-01
# iter 65: loss = 0.043919, gradnorm = 5.168872e-01, step length = 9.000e-01
# iter 66: loss = 0.036753, gradnorm = 4.325771e-01, step length = 9.000e-01
# iter 67: loss = 0.030736, gradnorm = 3.617588e-01, step length = 9.000e-01
# iter 68: loss = 0.025686, gradnorm = 3.022922e-01, step length = 9.000e-01
# iter 69: loss = 0.021447, gradnorm = 2.523700e-01, step length = 9.000e-01
# iter 70: loss = 0.017890, gradnorm = 2.104692e-01, step length = 9.000e-01
# iter 71: loss = 0.014906, gradnorm = 1.753076e-01, step length = 9.000e-01
# iter 72: loss = 0.012404, gradnorm = 1.458077e-01, step length = 9.000e-01
# iter 73: loss = 0.010305, gradnorm = 1.210644e-01, step length = 9.000e-01
# iter 74: loss = 0.008545, gradnorm = 1.003182e-01, step length = 9.000e-01
# iter 75: loss = 0.007071, gradnorm = 8.293186e-02, step length = 9.000e-01
# iter 76: loss = 0.005836, gradnorm = 6.837053e-02, step length = 9.000e-01
# iter 77: loss = 0.004803, gradnorm = 5.618534e-02, step length = 9.000e-01
# iter 78: loss = 0.003939, gradnorm = 4.599943e-02, step length = 9.000e-01
# iter 79: loss = 0.003218, gradnorm = 3.749655e-02, step length = 9.000e-01
# iter 80: loss = 0.002617, gradnorm = 3.041180e-02, step length = 9.000e-01
# iter 81: loss = 0.002117, gradnorm = 2.452340e-02, step length = 9.000e-01
# iter 82: loss = 0.001702, gradnorm = 1.964436e-02, step length = 9.000e-01
# iter 83: loss = 0.001360, gradnorm = 1.561503e-02, step length = 9.000e-01
# iter 84: loss = 0.001077, gradnorm = 1.229859e-02, step length = 9.000e-01
# iter 85: loss = 0.000845, gradnorm = 9.578942e-03, step length = 9.000e-01
# iter 86: loss = 0.000655, gradnorm = 7.360758e-03, step length = 9.000e-01
# iter 87: loss = 0.000501, gradnorm = 5.569543e-03, step length = 9.000e-01
# iter 88: loss = 0.000378, gradnorm = 4.141594e-03, step length = 9.000e-01
# iter 89: loss = 0.000281, gradnorm = 3.017503e-03, step length = 9.000e-01
# iter 90: loss = 0.000204, gradnorm = 2.145464e-03, step length = 9.000e-01
# iter 91: loss = 0.000145, gradnorm = 1.481152e-03, step length = 9.000e-01
# iter 92: loss = 0.000101, gradnorm = 9.897411e-04, step length = 9.000e-01
# Result: f = 0.0001008255, ||grad f|| = 9.897411e-04

# %%
# Plot the loss function 
fig = plt.figure()
plt.rcParams.update({'font.size': 16})
Loss_filter = Loss_vals[Loss_vals != 0]
plt.plot(Loss_filter,label = "Loss")
plt.xlabel("Iteration #")
plt.title("Loss function")
plt.yscale("log")
plt.savefig("task2 loss")

# %%
# Plot the norm of the gradient of the loss
fig = plt.figure()
plt.rcParams.update({'font.size': 16})
gradnorm_filter = gradnorm_vals[gradnorm_vals != 0]
plt.plot(gradnorm_filter,label = "||grad Loss||")
plt.xlabel("Iteration #")
plt.title("||grad Loss||")
plt.yscale("log")
plt.savefig("task2 gradnorm")
