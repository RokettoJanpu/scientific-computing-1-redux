# %%
import numpy as np
import numpy.linalg as la
import scipy as sp
import matplotlib.pyplot as plt

# %%
mnist = sp.io.loadmat('mnist.mat')
print(mnist.keys())
imgs = mnist['imgs_test']
imgs_x, imgs_y, imgs_z = imgs.shape
print(imgs.shape)
labels = mnist['labels_test']
print(labels.shape)
labels = labels.reshape(imgs_z)
print(labels.shape)
# imgs_z == labels.shape
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'imgs_test', 'imgs_train', 'labels_test', 'labels_train'])
# (20, 20, 10000)
# (10000, 1)
# (10000,)

# %%
# sample = imgs[:,:,19]
# print(sample.shape)
# print(sample)

# %%
# reshape imgs
imgs = imgs.transpose(2,0,1).reshape(imgs_z,-1)
print(imgs.shape)
# Out:
# (10000, 400)

# %%
# sample = imgs[19,:]
# print(samp.shape)
# print(samp)

# %%
# SVD of imgs
U, S, Vh = la.svd(imgs, full_matrices=False)
print(U.shape,S.shape,Vh.shape)
# Out:
# (10000, 400) (400,) (400, 400)

# %%
# first two right singular vectors
v1 = Vh[0,:]
v2 = Vh[1,:]
print(v1.shape,v2.shape)
# Out:
# (400,) (400,)

# %%
# project data onto span(v1,v2)
proj_v1 = imgs@v1
proj_v2 = imgs@v2

# %%
# pick data with label 0,1
proj_v1_0 = proj_v1[labels==0]
proj_v2_0 = proj_v2[labels==0]
proj_v1_1 = proj_v1[labels==1]
proj_v2_1 = proj_v2[labels==1]

# %%
# plot
plt.title('data projected onto span(v1,v2)')
plt.xlabel('v1')
plt.ylabel('v2', rotation=0)
plt.plot(proj_v1_0, proj_v2_0, label='digit 0')
plt.plot(proj_v1_1, proj_v2_1, label='digit 1')
plt.legend()
plt.show()
